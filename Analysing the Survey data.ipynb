# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('survey.csv')
df
# Out:
#      S.No           Name How would you rate the overall campus atmosphere?  \
# 0       1           Mani                                         Excellent
# 1       2          Saran                                              Good
# 2       3        Abinaya                                         Excellent
# 3       4         Ritesh                                              Good
# 4       5        Gobikka                                              Good
# ..    ...            ...                                               ...
# 245   246        Manoj v                                           Average
# 246   247     Lavaniya C                                         Excellent
# 247   248      Praveen j                                              Good
# 248   249       Mathan A                                           Average
# 249   250  Venkat Raman                                          Excellent
#
# ...

# %%
df.shape
# Out:
# (250, 17)

# %%
df.columns
# Out:
# Index(['S.No', 'Name', 'How would you rate the overall campus atmosphere?',
#        'Which aspect of the college environment do you find most appealing?',
#        'How satisfied are you with the availability of campus facilities (e.g., library, laboratories, recreational areas)?',
#        'How would you rate the accessibility of professors and staff members?',
#        'How often do you engage in extracurricular activities or student clubs?',
#        'How well do you think the college promotes diversity and inclusivity?',
#        'What is your perception of campus safety and security?',
#        'How satisfied are you with the quality of academic advising and career services?',
#        'How would you rate the availability and reliability of technology resources (e.g., Wi-Fi, computer labs)?',
#        'How often do you interact with students from different cultural or international backgrounds?',
# ...

# %%
df['How would you rate the overall campus atmosphere?'].value_counts()
# Out:
# Good         110
# Excellent     80
# Average       56
# Poor           4
# Name: How would you rate the overall campus atmosphere?, dtype: int64

# %%
df['How would you rate the overall campus atmosphere?'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Which aspect of the college environment do you find most appealing?'].value_counts()
# Out:
# Academic resources          93
# Campus facilities           78
# Social activities           46
# Student support services    33
# Name: Which aspect of the college environment do you find most appealing?, dtype: int64

# %%
df['Which aspect of the college environment do you find most appealing?'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['How satisfied are you with the availability of campus facilities (e.g., library, laboratories, recreational areas)?'].value_counts()
# Out:
# Satisfied            90
# Very satisfied       77
# Neutral              50
# Dissatisfied         24
# Very dissatisfied     9
# Name: How satisfied are you with the availability of campus facilities (e.g., library, laboratories, recreational areas)?, dtype: int64

# %%
df['How satisfied are you with the availability of campus facilities (e.g., library, laboratories, recreational areas)?'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['How would you rate the accessibility of professors and staff members?'].value_counts()
# Out:
# Accessible           93
# Very accessible      90
# Neutral              41
# Inaccessible         18
# Very inaccessible     8
# Name: How would you rate the accessibility of professors and staff members?, dtype: int64

# %%
df['How would you rate the accessibility of professors and staff members?'].value_counts().plot(kind='barh')
# Out:
# <Axes: >

# %%
df['How often do you engage in extracurricular activities or student clubs?'].value_counts()
# Out:
# Occasionally    111
# Frequently       91
# Rarely           40
# Never             8
# Name: How often do you engage in extracurricular activities or student clubs?, dtype: int64

# %%
df['How often do you engage in extracurricular activities or student clubs?'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['How well do you think the college promotes diversity and inclusivity?'].value_counts()
# Out:
# Well           83
# Neutral        69
# Very well      67
# Poorly         27
# Very poorly     4
# Name: How well do you think the college promotes diversity and inclusivity?, dtype: int64

# %%
df['How well do you think the college promotes diversity and inclusivity?'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['What is your perception of campus safety and security?'].value_counts()
# Out:
# Safe           95
# Very safe      80
# Neutral        50
# Unsafe         18
# Very unsafe     7
# Name: What is your perception of campus safety and security?, dtype: int64

# %%
df['What is your perception of campus safety and security?'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['How satisfied are you with the quality of academic advising and career services?'].value_counts()
# Out:
# Satisfied            80
# Very satisfied       75
# Neutral              52
# Dissatisfied         28
# Very dissatisfied    15
# Name: How satisfied are you with the quality of academic advising and career services?, dtype: int64

# %%
df['How satisfied are you with the quality of academic advising and career services?'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['How would you rate the availability and reliability of technology resources (e.g., Wi-Fi, computer labs)?'].value_counts()
# Out:
# Good         97
# Excellent    88
# Average      54
# Poor         11
# Name: How would you rate the availability and reliability of technology resources (e.g., Wi-Fi, computer labs)?, dtype: int64

# %%
df['How would you rate the availability and reliability of technology resources (e.g., Wi-Fi, computer labs)?'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['How often do you interact with students from different cultural or international backgrounds?'].value_counts()
# Out:
# Occasionally    108
# Frequently       81
# Rarely           50
# Never            11
# Name: How often do you interact with students from different cultural or international backgrounds?, dtype: int64

# %%
df['How often do you interact with students from different cultural or international backgrounds?'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['How well do you think the college supports student mental health and well-being?'].value_counts()
# Out:
# Very well      77
# Well           77
# Neutral        63
# Poorly         20
# Very poorly    13
# Name: How well do you think the college supports student mental health and well-being?, dtype: int64

# %%
df['How well do you think the college supports student mental health and well-being?'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['How satisfied are you with the course structure and material?'].value_counts()
# Out:
# Satisfied            89
# Very satisfied       77
# Neutral              52
# Dissatisfied         21
# Very dissatisfied    11
# Name: How satisfied are you with the course structure and material?, dtype: int64

# %%
df['How satisfied are you with the course structure and material?'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['How satisfied are you with the availability of food and cafeteria services?'].value_counts()
# Out:
# Satisfied            94
# Very satisfied       59
# Neutral              47
# Dissatisfied         37
# Very dissatisfied    13
# Name: How satisfied are you with the availability of food and cafeteria services?, dtype: int64

# %%
df['How satisfied are you with the availability of food and cafeteria services?'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['How satisfied are you with the availability of parking on campus?'].value_counts()
# Out:
# Satisfied            102
# Very satisfied        72
# Neutral               44
# Dissatisfied          23
# Very dissatisfied      9
# Name: How satisfied are you with the availability of parking on campus?, dtype: int64

# %%
df['How satisfied are you with the availability of parking on campus?'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['How likely are you to recommend this college to others based on your experience of the overall environment?'].value_counts()
# Out:
# Likely           81
# Very likely      73
# Neutral          52
# Unlikely         29
# Very unlikely    15
# Name: How likely are you to recommend this college to others based on your experience of the overall environment?, dtype: int64

# %%
df['How likely are you to recommend this college to others based on your experience of the overall environment?'].value_counts().plot(kind='bar')
# Out:
# <Axes: >
